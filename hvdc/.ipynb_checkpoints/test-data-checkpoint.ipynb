# %%
import os
import pandas as pd
import numpy as np
workpath = os.getcwd()
datapath = workpath + "/data/"

# Read csv file
df = pd.read_csv(datapath+"current.csv")
# convert into array data format
X = df.to_numpy()[:,1:].T
print(X.shape)
# Out:
# (16, 103)

# %%
cols = df.columns[1:]
y = np.array([s.split('/')[0] for s in cols])
print(y.shape)
# Out:
# (16,)

# %%
import matplotlib.pyplot as plt
plt.plot(X.T)
# Out:
# [<matplotlib.lines.Line2D at 0x1ae11498a00>,
#  <matplotlib.lines.Line2D at 0x1ae11498a30>,
#  <matplotlib.lines.Line2D at 0x1ae11498b50>,
#  <matplotlib.lines.Line2D at 0x1ae11498c70>,
#  <matplotlib.lines.Line2D at 0x1ae11498d90>,
#  <matplotlib.lines.Line2D at 0x1ae11498eb0>,
#  <matplotlib.lines.Line2D at 0x1ae11498fd0>,
#  <matplotlib.lines.Line2D at 0x1ae114a8130>,
#  <matplotlib.lines.Line2D at 0x1ae114a8250>,
#  <matplotlib.lines.Line2D at 0x1ae114a8370>,
#  <matplotlib.lines.Line2D at 0x1ae11474760>,
#  <matplotlib.lines.Line2D at 0x1ae114a8490>,
#  <matplotlib.lines.Line2D at 0x1ae114a86a0>,
#  <matplotlib.lines.Line2D at 0x1ae114a87c0>,
#  <matplotlib.lines.Line2D at 0x1ae114a88e0>,
#  <matplotlib.lines.Line2D at 0x1ae114a8a00>]

# %%
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
kernel = 1.0 * RBF(1.0)
gpc = GaussianProcessClassifier(kernel=kernel,random_state=0).fit(X, y)
gpc.score(X, y)
# Out:
# 1.0

# %%
gpc.predict_proba(X)
